# %%
import pandas as pd

listings = pd.read_csv(r"D:\a_PERSONAL\airbnb_data_engineering\data\raw\listings.csv")
calendar = pd.read_csv(r"D:\a_PERSONAL\airbnb_data_engineering\data\raw\calendar.csv")
reviews = pd.read_csv(r"D:\a_PERSONAL\airbnb_data_engineering\data\raw\reviews.csv")

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_profile_id', 'host_profile_url', 'host_name',
#        'host_since', 'hosts_time_as_user_years', 'hosts_time_as_user_months',
#        'hosts_time_as_host_years', 'hosts_time_as_host_months',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
# ...

# %%
reviews.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
calendar.columns
# Out:
# Index(['listing_id', 'date', 'available', 'minimum_nights', 'maximum_nights'], dtype='object')

# %%
listings.shape
# Out:
# (35036, 90)

# %%
calendar.shape
# Out:
# (12788141, 5)

# %%
reviews.shape
# Out:
# (1003299, 6)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35036 entries, 0 to 35035
# Data columns (total 90 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            35036 non-null  int64
#  1   listing_url                                   35036 non-null  object
#  2   scrape_id                                     35036 non-null  int64
#  3   last_scraped                                  35036 non-null  object
#  4   source                                        35036 non-null  object
#  5   name                                          35034 non-null  object
#  6   description                                   33517 non-null  object
#  7   neighborhood_overview                         0 non-null      float64
#  8   picture_url                                   34901 non-null  object
# ...

# %%
listings.isnull().sum()
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
#                                                 ...
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                               10494
# Length: 90, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
listings.isnull().sum()
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                2
# description                                      1519
# neighborhood_overview                           35036
# picture_url                                       135
# host_id                                             0
# host_url                                            0
# host_profile_id                                   840
# host_profile_url                                  904
# host_name                                         835
# host_since                                      35036
# hosts_time_as_user_years                          840
# hosts_time_as_user_months                         840
# ...

# %%
listings.isnull().sum()[listings.isnull().sum() > 0].sort_values(ascending=False)
# Out:
# host_since                     35036
# neighborhood_overview          35036
# host_thumbnail_url             35036
# host_neighbourhood             35036
# host_verifications             35036
# host_total_listings_count      35036
# host_acceptance_rate           35036
# host_response_time             35036
# host_response_rate             35036
# neighbourhood                  35036
# calendar_updated               35036
# instant_bookable               35036
# beds                           31275
# bathrooms                      31239
# license                        29974
# host_about                     15389
# price                          14343
# price_quote_price_per_night    14343
# price_quote_total_price        14343
# estimated_revenue_l365d        14343
# price_quote_checkout_date      13115
# price_quote_checkin_date       13115
# price_quote_raw                13115
# bedrooms                       12064
# review_scores_location         10511
# ...

# %%
listings.duplicated().sum()
# Out:
# np.int64(0)

# %%
listings.describe()
# Out:
#                  id     scrape_id  neighborhood_overview       host_id  \
# count  3.503600e+04  3.503600e+04                    0.0  3.503600e+04
# mean   5.007097e+17  2.026041e+13                    NaN  1.855502e+08
# std    5.815799e+17  0.000000e+00                    NaN  2.041843e+08
# min    6.848000e+03  2.026041e+13                    NaN  1.678000e+03
# 25%    2.158128e+07  2.026041e+13                    NaN  1.965853e+07
# 50%    5.148317e+07  2.026041e+13                    NaN  9.954958e+07
# 75%    1.030399e+18  2.026041e+13                    NaN  3.378483e+08
# max    1.654399e+18  2.026041e+13                    NaN  7.545790e+08
#
#        host_profile_id  host_since  hosts_time_as_user_years  \
# count     3.419600e+04         0.0              34196.000000
# mean      1.467166e+18         NaN                  8.454264
# std       1.219032e+16         NaN                  3.719542
# min       1.462506e+18         NaN                  0.000000
# ...
